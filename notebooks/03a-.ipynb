# %%
# !python -m pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ----- ---------------------------------- 15.5/113.8 MB 82.9 MB/s eta 0:00:02
#    ------------ --------------------------- 36.2/113.8 MB 90.5 MB/s eta 0:00:01
#    --------------- ------------------------ 43.3/113.8 MB 74.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 49.3/113.8 MB 61.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 64.5/113.8 MB 63.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 81.0/113.8 MB 65.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 97.3/113.8 MB 67.7 MB/s eta 0:00:01
#    --------------------------------------  113.0/113.8 MB 68.4 MB/s eta 0:00:01
#    --------------------------------------- 113.8/113.8 MB 63.6 MB/s eta 0:00:00
# ...

# %%
! set PATH = %PATH%;C:\Users\ugentguest\AppData\Roaming\Python\Python313\Scripts

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
